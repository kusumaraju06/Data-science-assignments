# %%
# Data Exploration and Preprocessing

import pandas as pd
data = pd.read_csv(r"C:\Users\KUSHMA\Downloads\Assignemnent Questions\adult_with_headers.csv")
data
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
summary_stats = data.describe(include='all')
data_info = data.info()
summary_stats, data_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# ...

# %%
print(data.describe(include='all'))
print(data.info())
# Out:
#                  age workclass        fnlwgt education  education_num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#              marital_status       occupation relationship    race    sex  \
# ...

# %%
# Calculate and print missing values for each column
missing_values = data.isnull().sum()
print(missing_values)

# Define a function to get fill values based on data type
def get_fill_value(series):
    if series.dtype == 'object':
        return series.mode()[0]
    else:
        return series.mean()

# Fill missing values in each column based on its type
for column in data.columns:
    if missing_values[column] > 0:  # Check if there are missing values
        fill_value = get_fill_value(data[column])
        data[column].fillna(fill_value, inplace=True)
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler_standard = StandardScaler()
data_standard_scaled = data.copy()
data_standard_scaled[data_standard_scaled.select_dtypes(include=['int64', 'float64']).columns] = scaler_standard.fit_transform(data_standard_scaled.select_dtypes(include=['int64', 'float64']))
data_standard_scaled
# Out:
#             age          workclass    fnlwgt    education  education_num  \
# 0      0.030671          State-gov -1.063611    Bachelors       1.134739
# 1      0.837109   Self-emp-not-inc -1.008707    Bachelors       1.134739
# 2     -0.042642            Private  0.245079      HS-grad      -0.420060
# 3      1.057047            Private  0.425801         11th      -1.197459
# 4     -0.775768            Private  1.408176    Bachelors       1.134739
# ...         ...                ...       ...          ...            ...
# 32556 -0.849080            Private  0.639741   Assoc-acdm       0.746039
# 32557  0.103983            Private -0.335433      HS-grad      -0.420060
# 32558  1.423610            Private -0.358777      HS-grad      -0.420060
# 32559 -1.215643            Private  0.110960      HS-grad      -0.420060
# 32560  0.983734       Self-emp-inc  0.929893      HS-grad      -0.420060
#
#             marital_status          occupation    relationship    race  \
# ...

# %%
scaler_minmax = MinMaxScaler()
data_minmax_scaled = data.copy()
data_minmax_scaled[data_minmax_scaled.select_dtypes(include=['int64', 'float64']).columns] = scaler_minmax.fit_transform(data_minmax_scaled.select_dtypes(include=['int64', 'float64']))
data_minmax_scaled
# Out:
#             age          workclass    fnlwgt    education  education_num  \
# 0      0.301370          State-gov  0.044302    Bachelors       0.800000
# 1      0.452055   Self-emp-not-inc  0.048238    Bachelors       0.800000
# 2      0.287671            Private  0.138113      HS-grad       0.533333
# 3      0.493151            Private  0.151068         11th       0.400000
# 4      0.150685            Private  0.221488    Bachelors       0.800000
# ...         ...                ...       ...          ...            ...
# 32556  0.136986            Private  0.166404   Assoc-acdm       0.733333
# 32557  0.315068            Private  0.096500      HS-grad       0.533333
# 32558  0.561644            Private  0.094827      HS-grad       0.533333
# 32559  0.068493            Private  0.128499      HS-grad       0.533333
# 32560  0.479452       Self-emp-inc  0.187203      HS-grad       0.533333
#
#             marital_status          occupation    relationship    race  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

# Identify categorical columns with fewer than 5 unique values
categorical_columns = data.select_dtypes(include=['object']).nunique()[lambda x: x < 5].index.tolist()

# Initialize OneHotEncoder
one_hot_encoder = OneHotEncoder(sparse_output=False, drop='first')

# Apply OneHotEncoder to the selected categorical columns
encoded_data = one_hot_encoder.fit_transform(data[categorical_columns])

# Create a DataFrame with the encoded features
encoded_df = pd.DataFrame(encoded_data, columns=one_hot_encoder.get_feature_names_out(categorical_columns))

# Concatenate the remaining data with the one-hot encoded features
data_one_hot_encoded = pd.concat([data.drop(columns=categorical_columns), encoded_df], axis=1)

# Display the final DataFrame with one-hot encoded features
data_one_hot_encoded
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to object-type columns that are not in categorical_columns
for col in data.select_dtypes(include=['object']).columns:
    if col not in categorical_columns:
        data[col] = label_encoder.fit_transform(data[col])

# Display the label encoder object
label_encoder
# Out:
# LabelEncoder()

# %%
# Create new features
data['hours_per_week_squared'] = data['hours_per_week'].pow(2)
data['age_income_ratio'] = data['age'] / (data['capital_gain'] + 1)

# Display the 'hours_per_week_squared' feature
data['hours_per_week_squared']
# Out:
# 0        1600
# 1         169
# 2        1600
# 3        1600
# 4        1600
#          ...
# 32556    1444
# 32557    1600
# 32558    1600
# 32559     400
# 32560    1600
# Name: hours_per_week_squared, Length: 32561, dtype: int64

# %%
data['age_income_ratio']
# Out:
# 0         0.017931
# 1        50.000000
# 2        38.000000
# 3        53.000000
# 4        28.000000
#            ...
# 32556    27.000000
# 32557    40.000000
# 32558    58.000000
# 32559    22.000000
# 32560     0.003461
# Name: age_income_ratio, Length: 32561, dtype: float64

# %%
# Create new features
data['hours_per_week_squared'] = data['hours_per_week'].pow(2)
data['age_income_ratio'] = data['age'] / (data['capital_gain'] + 1)

# Display the 'hours_per_week_squared' feature
data['hours_per_week_squared']
import numpy as np# Create new features
data['hours_per_week_squared'] = data['hours_per_week'].pow(2)
data['age_income_ratio'] = data['age'] / (data['capital_gain'] + 1)

# Display the 'hours_per_week_squared' feature
data['hours_per_week_squared']

data['capital_gain'] = np.log1p(data['capital_gain'])
data['capital_gain']
# Out:
# 0        7.684784
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
#            ...
# 32556    0.000000
# 32557    0.000000
# 32558    0.000000
# 32559    0.000000
# 32560    9.617471
# Name: capital_gain, Length: 32561, dtype: float64

# %%
# Feature Selection

from sklearn.ensemble import IsolationForest
iso_forest = IsolationForest(contamination=0.1)
outliers = iso_forest.fit_predict(data.select_dtypes(include=['int64', 'float64']))
data_no_outliers = data[outliers == 1]
iso_forest
# Out:
# IsolationForest(contamination=0.1)

# %%
outliers
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
data_no_outliers
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race      sex  capital_gain  capital_loss  \
# ...

# %%
# !pip install ppscore

# %%
# Apply PPS (Predictive Power Score):

import ppscore as pps
pps_matrix = pps.matrix(data)
pps_matrix

# %%
correlation_matrix = data.corr()
correlation_matrix
